# %% [markdown]
# 作業1：
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# UK Road Safety: Traffic Accidents and Vehicles
# Detailed dataset of road accidents and involved vehicles in the UK (2005-2017)
# https://www.kaggle.com/tsiaras/uk-road-safety-accidents-and-vehicles
#
# 1. 你選的這組資料為何重要:
#
#      天災不可避，人禍卻可免。可作為政府相關部門制定公共政策上的參考依據，此組資料相當全面，甚至可以
#      從數據解剖分析，從車輛製造到落地行駛，駕駛考照到行駛環境，反向對現行法規等措施改善，有效降低交通事故的發生率。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集):
#
#      英國政府的開放式數據網站，由英國交通部匯整(表格化)相關資料提供
#
# 3. 蒐集而來的資料型態為何:
#
#      資料包含兩個csv文件
#      屬結構化資料
#
# 4. 這組資料想解決的問題如何評估:
#
#      各{人事時地物}發生交通事件如何--事件共同特徵{人事時地物}排名--各情境發生預測--現有各{人事時地物}潛在安全問題
#
#
# 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#      假設為類似uber有系統、有自己的派案軟件(收集數據)的車隊，分為內部(配發端)與外部(載送服務端)，
#      以提升接客效率著手，司機接客率、地區接客率等，計算優化效率，提升業績
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#      軟件後台資料(乘客接送地區、司機服務地區、乘客司機駕乘習慣...)
#
# 3. 蒐集而來的資料型態為何
#
#      各結構化資料
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#      預測乘客乘車下車地點，以最近距離派發案件，提升每位司機接客效率，交叉比較各種派發模式
#
#
#
#      ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(y, yp):
    mse = MSE = (sum(abs(y - yp)**2)) / len(y)
    return mse

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 244.843
# The Mean absolute error is 11.781
